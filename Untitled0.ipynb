# %% [markdown]
# <a href="https://colab.research.google.com/github/DenI-10/Python_Course_/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Задача 44**
#
# В ячейке ниже представлен код генерирующий *DataFrame*, которая состоит всего из 1 столбца. Ваша задача перевести его в one *hot* вид. Сможете ли вы это сделать без *get_dummies?*

# %%
import pandas, seaborn, random

# %%
source_list = ['robot'] * 10 + ['human'] * 10
random.shuffle(source_list)
data_frame = pandas.DataFrame({'who_am_i': source_list})
data_frame.head(n=20)
# Out:
#    who_am_i
# 0     robot
# 1     human
# 2     robot
# 3     robot
# 4     robot
# 5     human
# 6     human
# 7     human
# 8     robot
# 9     robot
# 10    human
# 11    human
# 12    human
# 13    robot
# 14    robot
# 15    human
# 16    robot
# 17    robot
# 18    human
# 19    human

# %%
data_frame.loc[data_frame['who_am_i'] == 'robot', ['i_am_robot', 'i_am_human']] = [1, 0]
data_frame.loc[data_frame['who_am_i'] == 'human', ['i_am_human', 'i_am_robot']] = [1, 0]
data_frame.head(n=20)
# Out:
#    who_am_i  i_am_robot  i_am_human
# 0     robot         1.0         0.0
# 1     human         0.0         1.0
# 2     robot         1.0         0.0
# 3     robot         1.0         0.0
# 4     robot         1.0         0.0
# 5     human         0.0         1.0
# 6     human         0.0         1.0
# 7     human         0.0         1.0
# 8     robot         1.0         0.0
# 9     robot         1.0         0.0
# 10    human         0.0         1.0
# 11    human         0.0         1.0
# 12    human         0.0         1.0
# 13    robot         1.0         0.0
# 14    robot         1.0         0.0
# 15    human         0.0         1.0
# 16    robot         1.0         0.0
# 17    robot         1.0         0.0
# 18    human         0.0         1.0
# 19    human         0.0         1.0

# %%
seaborn.heatmap(data_frame[['i_am_robot', 'i_am_human']])
# Out:
# <Axes: >
